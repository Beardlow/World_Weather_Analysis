# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#Reviewing JSON Format to find weather description location
test_city = 'Boston'
test_url = url + "&q=" + test_city
test_json = requests.get(test_url).json
#print(test_url)
test_json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
# Create counters.
record_count = 1
set_count = 1
city_data = []
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(7)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | acapulco
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | tsumeb
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | acajutla
# Processing Record 8 of Set 1 | victoria
# Processing Record 9 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | daru
# Processing Record 14 of Set 1 | broken hill
# Processing Record 15 of Set 1 | grand forks
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | dubti
# Processing Record 18 of Set 1 | saint anthony
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | lasa
# Processing Record 21 of Set 1 | narasannapeta
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | montepuez
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | aklavik
# Processing Record 27 of Set 1 | sri aman
# Processing Record 28 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 1 | adrar
# Processing Record 30 of Set 1 | port-cartier
# Processing Record 31 of Set 1 | batagay
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | huilong
# Processing Record 35 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 1 | qaqortoq
# Processing Record 37 of Set 1 | mahebourg
# Processing Record 38 of Set 1 | sabha
# Processing Record 39 of Set 1 | fortuna
# Processing Record 40 of Set 1 | tuktoyaktuk
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | urumqi
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | calhoun
# Processing Record 46 of Set 1 | longyearbyen
# Processing Record 47 of Set 1 | airai
# Processing Record 48 of Set 1 | khandyga
# Processing Record 49 of Set 1 | kruisfontein
# Processing Record 50 of Set 1 | outjo
# Processing Record 1 of Set 2 | atar
# Processing Record 2 of Set 2 | boueni
# Processing Record 3 of Set 2 | celestun
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | cleveland
# Processing Record 6 of Set 2 | hovd
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | canby
# Processing Record 10 of Set 2 | olinda
# Processing Record 11 of Set 2 | tsentralnyy
# City not found. Skipping...
# Processing Record 12 of Set 2 | chokurdakh
# Processing Record 13 of Set 2 | banff
# Processing Record 14 of Set 2 | burnie
# Processing Record 15 of Set 2 | ust-ilimsk
# Processing Record 16 of Set 2 | rapar
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | mazamari
# Processing Record 19 of Set 2 | pisco
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | kavieng
# Processing Record 23 of Set 2 | marawi
# Processing Record 24 of Set 2 | broome
# Processing Record 25 of Set 2 | krasnoselkup
# Processing Record 26 of Set 2 | gasa
# Processing Record 27 of Set 2 | vao
# Processing Record 28 of Set 2 | kudahuvadhoo
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | provideniya
# Processing Record 31 of Set 2 | san felipe
# Processing Record 32 of Set 2 | olga
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | esperance
# Processing Record 35 of Set 2 | ribeira grande
# Processing Record 36 of Set 2 | constitucion
# Processing Record 37 of Set 2 | carnarvon
# Processing Record 38 of Set 2 | finnsnes
# Processing Record 39 of Set 2 | uncia
# Processing Record 40 of Set 2 | nouakchott
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | chany
# Processing Record 43 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 2 | meadow lake
# Processing Record 45 of Set 2 | ionia
# Processing Record 46 of Set 2 | jutai
# Processing Record 47 of Set 2 | sorong
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | clyde river
# Processing Record 50 of Set 2 | beaumont
# Processing Record 1 of Set 3 | mitu
# Processing Record 2 of Set 3 | lamar
# Processing Record 3 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 3 | ouesso
# Processing Record 5 of Set 3 | bengkulu
# Processing Record 6 of Set 3 | quatre cocos
# Processing Record 7 of Set 3 | siverek
# Processing Record 8 of Set 3 | sitka
# Processing Record 9 of Set 3 | bambous virieux
# Processing Record 10 of Set 3 | shelburne
# Processing Record 11 of Set 3 | la ronge
# Processing Record 12 of Set 3 | ahipara
# Processing Record 13 of Set 3 | victor harbor
# Processing Record 14 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 3 | talcahuano
# Processing Record 16 of Set 3 | manadhoo
# Processing Record 17 of Set 3 | lompoc
# Processing Record 18 of Set 3 | klamath falls
# Processing Record 19 of Set 3 | mangan
# Processing Record 20 of Set 3 | bluff
# Processing Record 21 of Set 3 | linguere
# Processing Record 22 of Set 3 | zyryanovsk
# Processing Record 23 of Set 3 | fairbanks
# Processing Record 24 of Set 3 | acuna
# City not found. Skipping...
# Processing Record 25 of Set 3 | svetlyy
# Processing Record 26 of Set 3 | half moon bay
# Processing Record 27 of Set 3 | saint george
# Processing Record 28 of Set 3 | mount pleasant
# Processing Record 29 of Set 3 | casambalangan
# Processing Record 30 of Set 3 | sandhaven
# City not found. Skipping...
# Processing Record 31 of Set 3 | komsomolskiy
# Processing Record 32 of Set 3 | qeshm
# Processing Record 33 of Set 3 | vaasa
# Processing Record 34 of Set 3 | rock island
# Processing Record 35 of Set 3 | yellowknife
# Processing Record 36 of Set 3 | severo-kurilsk
# Processing Record 37 of Set 3 | ulundi
# Processing Record 38 of Set 3 | kobryn
# Processing Record 39 of Set 3 | martapura
# Processing Record 40 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 3 | lagoa
# Processing Record 42 of Set 3 | saurimo
# Processing Record 43 of Set 3 | basyanovskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | umm kaddadah
# Processing Record 45 of Set 3 | mar del plata
# Processing Record 46 of Set 3 | kaitangata
# Processing Record 47 of Set 3 | guigue
# Processing Record 48 of Set 3 | iqaluit
# Processing Record 49 of Set 3 | nome
# Processing Record 50 of Set 3 | poum
# Processing Record 1 of Set 4 | poltavka
# Processing Record 2 of Set 4 | saint-augustin
# Processing Record 3 of Set 4 | nhulunbuy
# Processing Record 4 of Set 4 | khatanga
# Processing Record 5 of Set 4 | songjianghe
# Processing Record 6 of Set 4 | gull lake
# Processing Record 7 of Set 4 | sept-iles
# Processing Record 8 of Set 4 | butaritari
# Processing Record 9 of Set 4 | rio gallegos
# Processing Record 10 of Set 4 | hobyo
# Processing Record 11 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 12 of Set 4 | imeni poliny osipenko
# Processing Record 13 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 4 | katsuura
# Processing Record 15 of Set 4 | nagato
# Processing Record 16 of Set 4 | russell
# Processing Record 17 of Set 4 | svolvaer
# Processing Record 18 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 4 | qaanaaq
# Processing Record 20 of Set 4 | saint-georges
# Processing Record 21 of Set 4 | christchurch
# Processing Record 22 of Set 4 | piacabucu
# Processing Record 23 of Set 4 | port blair
# Processing Record 24 of Set 4 | taltal
# Processing Record 25 of Set 4 | gornopravdinsk
# Processing Record 26 of Set 4 | klaksvik
# Processing Record 27 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 4 | bandarbeyla
# Processing Record 29 of Set 4 | hasaki
# Processing Record 30 of Set 4 | tazovskiy
# Processing Record 31 of Set 4 | naze
# Processing Record 32 of Set 4 | carnot
# Processing Record 33 of Set 4 | waipawa
# Processing Record 34 of Set 4 | mitsamiouli
# Processing Record 35 of Set 4 | grand gaube
# Processing Record 36 of Set 4 | korla
# Processing Record 37 of Set 4 | kopanskaya
# Processing Record 38 of Set 4 | dunedin
# Processing Record 39 of Set 4 | lucapa
# Processing Record 40 of Set 4 | salalah
# Processing Record 41 of Set 4 | thinadhoo
# Processing Record 42 of Set 4 | tilichiki
# Processing Record 43 of Set 4 | antofagasta
# Processing Record 44 of Set 4 | san vicente
# Processing Record 45 of Set 4 | pangody
# Processing Record 46 of Set 4 | mehamn
# Processing Record 47 of Set 4 | sungaipenuh
# Processing Record 48 of Set 4 | port augusta
# Processing Record 49 of Set 4 | almaznyy
# Processing Record 50 of Set 4 | kosh-agach
# Processing Record 1 of Set 5 | chiali
# City not found. Skipping...
# Processing Record 2 of Set 5 | poso
# Processing Record 3 of Set 5 | diamantina
# Processing Record 4 of Set 5 | torbay
# Processing Record 5 of Set 5 | krasnozerskoye
# Processing Record 6 of Set 5 | port macquarie
# Processing Record 7 of Set 5 | pompeu
# Processing Record 8 of Set 5 | rocha
# Processing Record 9 of Set 5 | sioux lookout
# Processing Record 10 of Set 5 | kirundo
# Processing Record 11 of Set 5 | pitimbu
# Processing Record 12 of Set 5 | sangar
# Processing Record 13 of Set 5 | basco
# Processing Record 14 of Set 5 | gibsons
# Processing Record 15 of Set 5 | georgetown
# Processing Record 16 of Set 5 | pacific grove
# Processing Record 17 of Set 5 | sao paulo do potengi
# Processing Record 18 of Set 5 | tasiilaq
# Processing Record 19 of Set 5 | upata
# Processing Record 20 of Set 5 | pevek
# Processing Record 21 of Set 5 | miquelon
# Processing Record 22 of Set 5 | sorland
# Processing Record 23 of Set 5 | mount gambier
# Processing Record 24 of Set 5 | souillac
# Processing Record 25 of Set 5 | san ramon
# Processing Record 26 of Set 5 | thompson
# Processing Record 27 of Set 5 | molteno
# Processing Record 28 of Set 5 | burns lake
# Processing Record 29 of Set 5 | ust-nera
# Processing Record 30 of Set 5 | ilulissat
# Processing Record 31 of Set 5 | vestmanna
# Processing Record 32 of Set 5 | ponta do sol
# Processing Record 33 of Set 5 | xining
# Processing Record 34 of Set 5 | warrnambool
# Processing Record 35 of Set 5 | igrim
# Processing Record 36 of Set 5 | yerbogachen
# Processing Record 37 of Set 5 | saldanha
# Processing Record 38 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 5 | buala
# Processing Record 40 of Set 5 | pembroke
# Processing Record 41 of Set 5 | moranbah
# Processing Record 42 of Set 5 | axim
# Processing Record 43 of Set 5 | betioky
# Processing Record 44 of Set 5 | ixtapa
# Processing Record 45 of Set 5 | baijiantan
# Processing Record 46 of Set 5 | correntina
# Processing Record 47 of Set 5 | den helder
# Processing Record 48 of Set 5 | arraial do cabo
# Processing Record 49 of Set 5 | kodiak
# Processing Record 50 of Set 5 | kieta
# Processing Record 1 of Set 6 | atlantic city
# Processing Record 2 of Set 6 | vila velha
# Processing Record 3 of Set 6 | san cristobal
# Processing Record 4 of Set 6 | tadine
# Processing Record 5 of Set 6 | road town
# Processing Record 6 of Set 6 | marshall
# Processing Record 7 of Set 6 | evensk
# Processing Record 8 of Set 6 | portland
# Processing Record 9 of Set 6 | berlevag
# Processing Record 10 of Set 6 | margate
# Processing Record 11 of Set 6 | east london
# Processing Record 12 of Set 6 | ayorou
# Processing Record 13 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 6 | swan hill
# Processing Record 15 of Set 6 | xai-xai
# Processing Record 16 of Set 6 | rovaniemi
# Processing Record 17 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 6 | aginskoye
# Processing Record 20 of Set 6 | luderitz
# Processing Record 21 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 22 of Set 6 | riberalta
# Processing Record 23 of Set 6 | ise
# Processing Record 24 of Set 6 | pangnirtung
# Processing Record 25 of Set 6 | new norfolk
# Processing Record 26 of Set 6 | la asuncion
# Processing Record 27 of Set 6 | cabo san lucas
# Processing Record 28 of Set 6 | halifax
# Processing Record 29 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 6 | resende
# Processing Record 31 of Set 6 | makakilo city
# Processing Record 32 of Set 6 | ginir
# Processing Record 33 of Set 6 | guerrero negro
# Processing Record 34 of Set 6 | pierre
# Processing Record 35 of Set 6 | zabid
# Processing Record 36 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 37 of Set 6 | taft
# Processing Record 38 of Set 6 | mumford
# Processing Record 39 of Set 6 | sao joao da barra
# Processing Record 40 of Set 6 | elko
# Processing Record 41 of Set 6 | atambua
# Processing Record 42 of Set 6 | flagstaff
# Processing Record 43 of Set 6 | bilibino
# Processing Record 44 of Set 6 | marzuq
# Processing Record 45 of Set 6 | macherla
# Processing Record 46 of Set 6 | tiarei
# Processing Record 47 of Set 6 | elizabeth city
# Processing Record 48 of Set 6 | sao raimundo nonato
# Processing Record 49 of Set 6 | touros
# Processing Record 50 of Set 6 | cherskiy
# Processing Record 1 of Set 7 | oranjemund
# Processing Record 2 of Set 7 | saint-louis
# Processing Record 3 of Set 7 | franklin
# Processing Record 4 of Set 7 | upington
# Processing Record 5 of Set 7 | vyartsilya
# Processing Record 6 of Set 7 | ushtobe
# Processing Record 7 of Set 7 | umm lajj
# Processing Record 8 of Set 7 | dingle
# Processing Record 9 of Set 7 | sao filipe
# Processing Record 10 of Set 7 | hervey bay
# Processing Record 11 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 7 | port elizabeth
# Processing Record 13 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 7 | bugiri
# Processing Record 15 of Set 7 | mana
# Processing Record 16 of Set 7 | qasigiannguit
# Processing Record 17 of Set 7 | manzhouli
# Processing Record 18 of Set 7 | kenai
# Processing Record 19 of Set 7 | blagoyevo
# Processing Record 20 of Set 7 | arlit
# Processing Record 21 of Set 7 | archidona
# Processing Record 22 of Set 7 | cidreira
# Processing Record 23 of Set 7 | kathu
# Processing Record 24 of Set 7 | ilhabela
# Processing Record 25 of Set 7 | port hardy
# Processing Record 26 of Set 7 | shingu
# Processing Record 27 of Set 7 | alta floresta
# Processing Record 28 of Set 7 | voi
# Processing Record 29 of Set 7 | baturaja
# Processing Record 30 of Set 7 | avera
# Processing Record 31 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 7 | marcala
# Processing Record 33 of Set 7 | cayenne
# Processing Record 34 of Set 7 | adre
# Processing Record 35 of Set 7 | vedaranniyam
# City not found. Skipping...
# Processing Record 36 of Set 7 | catuday
# Processing Record 37 of Set 7 | flinders
# Processing Record 38 of Set 7 | beipiao
# Processing Record 39 of Set 7 | upernavik
# Processing Record 40 of Set 7 | verkhoyansk
# Processing Record 41 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 7 | agirish
# Processing Record 43 of Set 7 | ugoofaaru
# Processing Record 44 of Set 7 | oudtshoorn
# Processing Record 45 of Set 7 | borba
# Processing Record 46 of Set 7 | yeletskiy
# City not found. Skipping...
# Processing Record 47 of Set 7 | tual
# Processing Record 48 of Set 7 | seoul
# Processing Record 49 of Set 7 | awjilah
# Processing Record 50 of Set 7 | santiago de cao
# Processing Record 1 of Set 8 | marystown
# Processing Record 2 of Set 8 | mudgee
# Processing Record 3 of Set 8 | srednekolymsk
# Processing Record 4 of Set 8 | vanimo
# Processing Record 5 of Set 8 | helmsdale
# Processing Record 6 of Set 8 | garowe
# Processing Record 7 of Set 8 | talnakh
# Processing Record 8 of Set 8 | samarai
# Processing Record 9 of Set 8 | coihaique
# Processing Record 10 of Set 8 | baculin
# Processing Record 11 of Set 8 | lanivtsi
# Processing Record 12 of Set 8 | owosso
# Processing Record 13 of Set 8 | aiken
# Processing Record 14 of Set 8 | gigmoto
# Processing Record 15 of Set 8 | nemuro
# Processing Record 16 of Set 8 | quimper
# Processing Record 17 of Set 8 | odweyne
# Processing Record 18 of Set 8 | havoysund
# Processing Record 19 of Set 8 | volnoye
# Processing Record 20 of Set 8 | vastse-kuuste
# Processing Record 21 of Set 8 | nefteyugansk
# Processing Record 22 of Set 8 | yulara
# Processing Record 23 of Set 8 | bentiu
# Processing Record 24 of Set 8 | abbeville
# Processing Record 25 of Set 8 | ous
# Processing Record 26 of Set 8 | rawson
# Processing Record 27 of Set 8 | sundsvall
# Processing Record 28 of Set 8 | jalandhar
# Processing Record 29 of Set 8 | astana
# Processing Record 30 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 8 | orbetello
# Processing Record 32 of Set 8 | huanren
# Processing Record 33 of Set 8 | kattivakkam
# Processing Record 34 of Set 8 | vitim
# Processing Record 35 of Set 8 | bijie
# Processing Record 36 of Set 8 | solnechnyy
# Processing Record 37 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 38 of Set 8 | ayagoz
# Processing Record 39 of Set 8 | yantal
# Processing Record 40 of Set 8 | nanortalik
# Processing Record 41 of Set 8 | banda aceh
# Processing Record 42 of Set 8 | cairns
# Processing Record 43 of Set 8 | russkaya polyana
# Processing Record 44 of Set 8 | bambui
# Processing Record 45 of Set 8 | faanui
# Processing Record 46 of Set 8 | aksarka
# Processing Record 47 of Set 8 | grand-lahou
# Processing Record 48 of Set 8 | anqiu
# Processing Record 49 of Set 8 | trancoso
# Processing Record 50 of Set 8 | paris
# Processing Record 1 of Set 9 | ponta delgada
# Processing Record 2 of Set 9 | tukrah
# Processing Record 3 of Set 9 | caucaia
# Processing Record 4 of Set 9 | ancud
# Processing Record 5 of Set 9 | kupang
# Processing Record 6 of Set 9 | waitara
# Processing Record 7 of Set 9 | lorengau
# Processing Record 8 of Set 9 | namibe
# Processing Record 9 of Set 9 | eureka
# Processing Record 10 of Set 9 | ust-maya
# Processing Record 11 of Set 9 | omsukchan
# Processing Record 12 of Set 9 | saskylakh
# Processing Record 13 of Set 9 | coahuayana
# Processing Record 14 of Set 9 | canitas
# City not found. Skipping...
# Processing Record 15 of Set 9 | lakatoro
# Processing Record 16 of Set 9 | wanganui
# Processing Record 17 of Set 9 | westport
# Processing Record 18 of Set 9 | dukat
# Processing Record 19 of Set 9 | sistranda
# Processing Record 20 of Set 9 | ostrovnoy
# Processing Record 21 of Set 9 | samaro
# Processing Record 22 of Set 9 | lugovoy
# Processing Record 23 of Set 9 | verkhnyaya inta
# Processing Record 24 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 9 | tautira
# Processing Record 26 of Set 9 | finschhafen
# Processing Record 27 of Set 9 | villa bruzual
# Processing Record 28 of Set 9 | mporokoso
# Processing Record 29 of Set 9 | vrangel
# Processing Record 30 of Set 9 | cap malheureux
# Processing Record 31 of Set 9 | killybegs
# Processing Record 32 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 9 | wajima
# Processing Record 34 of Set 9 | saint-paul
# Processing Record 35 of Set 9 | pitelino
# Processing Record 36 of Set 9 | jalingo
# Processing Record 37 of Set 9 | ketchikan
# Processing Record 38 of Set 9 | atka
# City not found. Skipping...
# Processing Record 39 of Set 9 | vila do maio
# Processing Record 40 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 9 | watertown
# Processing Record 42 of Set 9 | rudnichnyy
# Processing Record 43 of Set 9 | ahuimanu
# Processing Record 44 of Set 9 | terrace
# Processing Record 45 of Set 9 | repatriacion
# Processing Record 46 of Set 9 | namatanai
# Processing Record 47 of Set 9 | kushiro
# Processing Record 48 of Set 9 | vardo
# Processing Record 49 of Set 9 | barra do garcas
# Processing Record 50 of Set 9 | severo-yeniseyskiy
# Processing Record 1 of Set 10 | bela
# Processing Record 2 of Set 10 | college
# Processing Record 3 of Set 10 | guaraciaba do norte
# Processing Record 4 of Set 10 | rio tercero
# Processing Record 5 of Set 10 | chacarita
# Processing Record 6 of Set 10 | pervoye maya
# Processing Record 7 of Set 10 | letka
# Processing Record 8 of Set 10 | leshukonskoye
# Processing Record 9 of Set 10 | puerto morazan
# Processing Record 10 of Set 10 | glendive
# Processing Record 11 of Set 10 | tabou
# Processing Record 12 of Set 10 | noumea
# Processing Record 13 of Set 10 | coyah
# Processing Record 14 of Set 10 | bathsheba
# Processing Record 15 of Set 10 | guaimaro
# Processing Record 16 of Set 10 | darhan
# Processing Record 17 of Set 10 | haines junction
# Processing Record 18 of Set 10 | le vauclin
# Processing Record 19 of Set 10 | pukhrayan
# Processing Record 20 of Set 10 | ifo
# Processing Record 21 of Set 10 | payo
# Processing Record 22 of Set 10 | monte carmelo
# Processing Record 23 of Set 10 | teahupoo
# Processing Record 24 of Set 10 | gorom-gorom
# Processing Record 25 of Set 10 | sinnamary
# Processing Record 26 of Set 10 | smila
# Processing Record 27 of Set 10 | padang
# Processing Record 28 of Set 10 | anadyr
# Processing Record 29 of Set 10 | inhambane
# Processing Record 30 of Set 10 | kapit
# Processing Record 31 of Set 10 | narsaq
# Processing Record 32 of Set 10 | elmadag
# Processing Record 33 of Set 10 | wattegama
# Processing Record 34 of Set 10 | menongue
# Processing Record 35 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 10 | atherton
# Processing Record 37 of Set 10 | gari
# Processing Record 38 of Set 10 | orlik
# Processing Record 39 of Set 10 | ucluelet
# Processing Record 40 of Set 10 | xichang
# Processing Record 41 of Set 10 | gravdal
# Processing Record 42 of Set 10 | katobu
# Processing Record 43 of Set 10 | lata
# Processing Record 44 of Set 10 | nabinagar
# Processing Record 45 of Set 10 | sur
# Processing Record 46 of Set 10 | marienburg
# Processing Record 47 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 10 | tromso
# Processing Record 49 of Set 10 | asau
# Processing Record 50 of Set 10 | kadoma
# Processing Record 1 of Set 11 | carman
# Processing Record 2 of Set 11 | zharkovskiy
# Processing Record 3 of Set 11 | karratha
# Processing Record 4 of Set 11 | sampit
# Processing Record 5 of Set 11 | abu dhabi
# Processing Record 6 of Set 11 | tura
# Processing Record 7 of Set 11 | general roca
# Processing Record 8 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 11 | tahta
# Processing Record 10 of Set 11 | barra
# Processing Record 11 of Set 11 | clarence town
# Processing Record 12 of Set 11 | cockburn town
# Processing Record 13 of Set 11 | thoen
# Processing Record 14 of Set 11 | asha
# Processing Record 15 of Set 11 | zyryanka
# Processing Record 16 of Set 11 | khotynets
# Processing Record 17 of Set 11 | balkhash
# Processing Record 18 of Set 11 | kodinsk
# Processing Record 19 of Set 11 | tamandare
# Processing Record 20 of Set 11 | vanavara
# Processing Record 21 of Set 11 | plouzane
# Processing Record 22 of Set 11 | pandamatenga
# Processing Record 23 of Set 11 | mount isa
# Processing Record 24 of Set 11 | sola
# Processing Record 25 of Set 11 | hede
# Processing Record 26 of Set 11 | san patricio
# Processing Record 27 of Set 11 | crystal beach
# Processing Record 28 of Set 11 | bure
# Processing Record 29 of Set 11 | kapitan ramon
# Processing Record 30 of Set 11 | hamilton
# Processing Record 31 of Set 11 | hualmay
# Processing Record 32 of Set 11 | chicama
# Processing Record 33 of Set 11 | teyateyaneng
# Processing Record 34 of Set 11 | kuito
# Processing Record 35 of Set 11 | kahului
# Processing Record 36 of Set 11 | kabompo
# Processing Record 37 of Set 11 | ukiah
# Processing Record 38 of Set 11 | bontang
# Processing Record 39 of Set 11 | toamasina
# Processing Record 40 of Set 11 | prieska
# Processing Record 41 of Set 11 | visnes
# Processing Record 42 of Set 11 | gorontalo
# Processing Record 43 of Set 11 | kulhudhuffushi
# Processing Record 44 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 11 | isangel
# Processing Record 46 of Set 11 | nuuk
# Processing Record 47 of Set 11 | conakry
# Processing Record 48 of Set 11 | ihosy
# Processing Record 49 of Set 11 | salinopolis
# Processing Record 50 of Set 11 | nouadhibou
# Processing Record 1 of Set 12 | salaga
# Processing Record 2 of Set 12 | broadstairs
# Processing Record 3 of Set 12 | tolmachevo
# Processing Record 4 of Set 12 | bac lieu
# Processing Record 5 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 6 of Set 12 | sao jose da coroa grande
# Processing Record 7 of Set 12 | jalu
# Processing Record 8 of Set 12 | riyadh
# Processing Record 9 of Set 12 | nicoya
# Processing Record 10 of Set 12 | stekolnyy
# City not found. Skipping...
# Processing Record 11 of Set 12 | olafsvik
# Processing Record 12 of Set 12 | knysna
# Processing Record 13 of Set 12 | tokur
# Processing Record 14 of Set 12 | trairi
# Processing Record 15 of Set 12 | chuy
# Processing Record 16 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 12 | ismailia
# Processing Record 18 of Set 12 | luau
# Processing Record 19 of Set 12 | abu zabad
# Processing Record 20 of Set 12 | raton
# Processing Record 21 of Set 12 | tiksi
# Processing Record 22 of Set 12 | byron bay
# Processing Record 23 of Set 12 | inta
# Processing Record 24 of Set 12 | barra patuca
# Processing Record 25 of Set 12 | bilma
# Processing Record 26 of Set 12 | nortelandia
# Processing Record 27 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 28 of Set 12 | namwala
# Processing Record 29 of Set 12 | dudinka
# Processing Record 30 of Set 12 | emerald
# Processing Record 31 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 12 | pandan
# Processing Record 33 of Set 12 | snezhnogorsk
# Processing Record 34 of Set 12 | husavik
# Processing Record 35 of Set 12 | maarianhamina
# Processing Record 36 of Set 12 | nola
# Processing Record 37 of Set 12 | matagami
# Processing Record 38 of Set 12 | necochea
# Processing Record 39 of Set 12 | vulcan
# Processing Record 40 of Set 12 | lakes entrance
# Processing Record 41 of Set 12 | amapa
# Processing Record 42 of Set 12 | luanda
# Processing Record 43 of Set 12 | rundu
# Processing Record 44 of Set 12 | sinjai
# Processing Record 45 of Set 12 | greensburg
# Processing Record 46 of Set 12 | trelew
# Processing Record 47 of Set 12 | burica
# City not found. Skipping...
# Processing Record 48 of Set 12 | shimoda
# Processing Record 49 of Set 12 | nishihara
# Processing Record 50 of Set 12 | mpanda
# Processing Record 1 of Set 13 | veraval
# Processing Record 2 of Set 13 | bodden town
# Processing Record 3 of Set 13 | koulamoutou
# Processing Record 4 of Set 13 | cortez
# Processing Record 5 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 13 | sarankhola
# Processing Record 7 of Set 13 | taoudenni
# Processing Record 8 of Set 13 | niort
# Processing Record 9 of Set 13 | obera
# Processing Record 10 of Set 13 | norman wells
# Processing Record 11 of Set 13 | tuatapere
# Processing Record 12 of Set 13 | nobeoka
# Processing Record 13 of Set 13 | barwaha
# City not found. Skipping...
# Processing Record 14 of Set 13 | plaster rock
# Processing Record 15 of Set 13 | anchorage
# Processing Record 16 of Set 13 | santa rosalia
# Processing Record 17 of Set 13 | jinchang
# Processing Record 18 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 13 | ola
# Processing Record 20 of Set 13 | mbini
# Processing Record 21 of Set 13 | nambucca heads
# Processing Record 22 of Set 13 | oranjestad
# Processing Record 23 of Set 13 | puerto colombia
# Processing Record 24 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 25 of Set 13 | abatskoye
# Processing Record 26 of Set 13 | calama
# Processing Record 27 of Set 13 | port lincoln
# Processing Record 28 of Set 13 | newport
# Processing Record 29 of Set 13 | savannah bight
# Processing Record 30 of Set 13 | coquimbo
# Processing Record 31 of Set 13 | kirakira
# Processing Record 32 of Set 13 | paraiso
# Processing Record 33 of Set 13 | dubrovnik
# Processing Record 34 of Set 13 | papara
# Processing Record 35 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 13 | goderich
# Processing Record 37 of Set 13 | ivdel
# Processing Record 38 of Set 13 | ngunguru
# Processing Record 39 of Set 13 | auki
# Processing Record 40 of Set 13 | gushikawa
# Processing Record 41 of Set 13 | trat
# Processing Record 42 of Set 13 | lewistown
# Processing Record 43 of Set 13 | kutum
# Processing Record 44 of Set 13 | ternate
# Processing Record 45 of Set 13 | herat
# Processing Record 46 of Set 13 | eidsvag
# Processing Record 47 of Set 13 | rio grande
# Processing Record 48 of Set 13 | caravelas
# Processing Record 49 of Set 13 | miles city
# Processing Record 50 of Set 13 | richards bay
# Processing Record 1 of Set 14 | okara
# Processing Record 2 of Set 14 | sakakah
# Processing Record 3 of Set 14 | vidim
# Processing Record 4 of Set 14 | fakel
# Processing Record 5 of Set 14 | kimbe
# Processing Record 6 of Set 14 | mnogovershinnyy
# Processing Record 7 of Set 14 | hofn
# Processing Record 8 of Set 14 | poya
# Processing Record 9 of Set 14 | palmer
# Processing Record 10 of Set 14 | anloga
# Processing Record 11 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 12 of Set 14 | maceio
# Processing Record 13 of Set 14 | tomohon
# Processing Record 14 of Set 14 | quelimane
# Processing Record 15 of Set 14 | paranaiba
# Processing Record 16 of Set 14 | rapid valley
# Processing Record 17 of Set 14 | twin falls
# Processing Record 18 of Set 14 | yarmouth
# Processing Record 19 of Set 14 | roald
# Processing Record 20 of Set 14 | alihe
# Processing Record 21 of Set 14 | atasu
# Processing Record 22 of Set 14 | barberton
# Processing Record 23 of Set 14 | san-pedro
# Processing Record 24 of Set 14 | cootamundra
# Processing Record 25 of Set 14 | toronto
# Processing Record 26 of Set 14 | khorixas
# Processing Record 27 of Set 14 | ghanzi
# Processing Record 28 of Set 14 | fayaoue
# Processing Record 29 of Set 14 | gat
# Processing Record 30 of Set 14 | vostok
# Processing Record 31 of Set 14 | pecanha
# Processing Record 32 of Set 14 | fuyang
# Processing Record 33 of Set 14 | yeppoon
# Processing Record 34 of Set 14 | assiniboia
# Processing Record 35 of Set 14 | mayya
# Processing Record 36 of Set 14 | vestmannaeyjar
# Processing Record 37 of Set 14 | napasar
# Processing Record 38 of Set 14 | slave lake
# Processing Record 39 of Set 14 | paamiut
# Processing Record 40 of Set 14 | yacuiba
# Processing Record 41 of Set 14 | aviles
# Processing Record 42 of Set 14 | lundazi
# Processing Record 43 of Set 14 | pemberton
# Processing Record 44 of Set 14 | champerico
# Processing Record 45 of Set 14 | mayumba
# Processing Record 46 of Set 14 | mecca
# Processing Record 47 of Set 14 | aktash
# Processing Record 48 of Set 14 | kajaani
# Processing Record 49 of Set 14 | ambilobe
# Processing Record 50 of Set 14 | vangaindrano
# Processing Record 1 of Set 15 | raudeberg
# Processing Record 2 of Set 15 | camacha
# Processing Record 3 of Set 15 | savinka
# Processing Record 4 of Set 15 | mwinilunga
# Processing Record 5 of Set 15 | negombo
# Processing Record 6 of Set 15 | labuhan
# Processing Record 7 of Set 15 | afrikanda
# Processing Record 8 of Set 15 | libourne
# Processing Record 9 of Set 15 | muros
# Processing Record 10 of Set 15 | baft
# Processing Record 11 of Set 15 | faya
# Processing Record 12 of Set 15 | kitgum
# Processing Record 13 of Set 15 | the valley
# Processing Record 14 of Set 15 | maanshan
# Processing Record 15 of Set 15 | lavrentiya
# Processing Record 16 of Set 15 | torrevieja
# Processing Record 17 of Set 15 | udachnyy
# Processing Record 18 of Set 15 | perbaungan
# Processing Record 19 of Set 15 | svetlogorsk
# Processing Record 20 of Set 15 | maniitsoq
# Processing Record 21 of Set 15 | tarakan
# Processing Record 22 of Set 15 | whitehorse
# Processing Record 23 of Set 15 | dutse
# Processing Record 24 of Set 15 | zaoyang
# Processing Record 25 of Set 15 | nantucket
# Processing Record 26 of Set 15 | comodoro rivadavia
# Processing Record 27 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 15 | mbacke
# City not found. Skipping...
# Processing Record 29 of Set 15 | aykhal
# Processing Record 30 of Set 15 | malaya serdoba
# Processing Record 31 of Set 15 | sterling
# Processing Record 32 of Set 15 | itoman
# Processing Record 33 of Set 15 | maragogi
# Processing Record 34 of Set 15 | santa maria
# Processing Record 35 of Set 15 | saint-leu
# Processing Record 36 of Set 15 | ravar
# Processing Record 37 of Set 15 | havelock
# Processing Record 38 of Set 15 | nedelino
# Processing Record 39 of Set 15 | soyo
# Processing Record 40 of Set 15 | belfast
# Processing Record 41 of Set 15 | chiredzi
# Processing Record 42 of Set 15 | dachau
# Processing Record 43 of Set 15 | egvekinot
# Processing Record 44 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 45 of Set 15 | imeni zhelyabova
# Processing Record 46 of Set 15 | karpathos
# Processing Record 47 of Set 15 | praia da vitoria
# Processing Record 48 of Set 15 | sarahan
# Processing Record 49 of Set 15 | tuy hoa
# Processing Record 50 of Set 15 | kamwenge
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_raw_df = pd.DataFrame(city_data)
city_data_raw_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Acapulco  16.8634  -99.8901     87.62        70          40
# 1       Ushuaia -54.8000  -68.3000     31.66        93         100
# 2  Punta Arenas -53.1500  -70.9167     35.71        64          75
# 3        Dikson  73.5069   80.5464     44.02        67          10
# 4        Tsumeb -19.2333   17.7167     63.09        25           2
# 5        Albany  42.6001  -73.9662     95.04        45           6
# 6      Acajutla  13.5928  -89.8275     87.73        57          36
# 7      Victoria  22.2855  114.1577     87.33        85          24
# 8        Avarua -21.2078 -159.7750     73.45        73          75
# 9        Hobart -42.8794  147.3294     35.06        93           1
#
#    Wind Speed Country                 Date Current Description
# 0        8.05      MX  2022-07-20 18:27:50    scattered clouds
# 1       24.16      AR  2022-07-20 18:27:50          light snow
# 2       24.16      CL  2022-07-20 18:27:50       broken clouds
# 3       21.52      RU  2022-07-20 18:27:51           clear sky
# 4        9.26      NA  2022-07-20 18:27:51           clear sky
# 5        3.74      US  2022-07-20 18:24:12           clear sky
# 6        7.18      SV  2022-07-20 18:27:51    scattered clouds
# 7        4.00      HK  2022-07-20 18:24:08          few clouds
# 8       16.11      CK  2022-07-20 18:27:52       broken clouds
# 9        8.05      AU  2022-07-20 18:27:52           clear sky

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description', 'Date']
city_data_df = city_data_raw_df[new_column_order]
#city_data_df

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
